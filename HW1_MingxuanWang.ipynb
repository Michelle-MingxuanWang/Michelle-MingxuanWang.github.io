# %% [markdown]
# ## Homework 1 - Mingxuan Wang
# Github Username: Michelle-MingxuanWang
# Github Repository: https://github.com/Michelle-MingxuanWang/Michelle-MingxuanWang.github.io
# Blog: https://michelle-mingxuanwang.github.io

# %%
# Problem 6, Solved by 496349
def sum_square_diff(n):
    """
    Parameters
    ----------
    n : int
        Number of the first several natural numbers.
    i : int
        Index of the number.
        
    Returns
    -------
    res : int
         The difference between the sum of the squares of the first one hundred natural numbers and the square of the sum.
    """
    res = (sum(list(i for i in range(1,n+1))))**2-sum(list(i**2 for i in range(1,n+1))) 
    return res
sum_square_diff(100)
# Out:
# 25164150

# %%
# Problem 31, Solved by 85886
def coin_sums(n):
    """
    Parameters
    ----------
    n : int
        Total amount.
    a, b, c, d, e, f : int
        Number of the coins of each value
    cnt : int
        Number of different ways that the amount of money can be made using coins.  
    
    Returns
    -------
    cnt : int
         Number of different ways that the amount of money can be made using coins.  
    """
    cnt=1
    for a in range(0,3):
        for b in range(0,5):
            for c in range(0,11):
                for d in range(0,21):
                    for e in range(0,41):
                        for f in range(0,101):
                            if a*100+b*50+c*20+d*10+e*5+f*2<n+1:
                                    cnt+=1
    return cnt
coin_sums(200)
# Out:
# 73682

# %%
# Problem 206, Solved by 24163
#Find the unique positive integer whose square has the form 1_2_3_4_5_6_7_8_9_0,
#where each “_” is a single digit.
def concealed_square():
    """
    Parameters
    ----------
    i : int
        The number we need to find.
    sq : int
        Square of the number.
        
    Returns
    -------
    i : int
        The unique positive integer that we need to find.
        
    See Also
    --------
        np.sqrt : Calculate the square root of the number. 
    """
    import numpy as np
    for i in range(10**9,int(np.sqrt(2)*10**9)+1,10):
        sq = i**2
        if sq//100%10 == 9 and sq//10000%10 == 8 and sq//10**6%10 == 7 and sq//10**8%10 == 6 and sq//10**10%10 == 5 and sq//10**12%10 == 4 and sq//10**14%10 == 3 and sq//10**16%10 == 2:
            break
    return i
concealed_square()
# Out:
# 1389019170
